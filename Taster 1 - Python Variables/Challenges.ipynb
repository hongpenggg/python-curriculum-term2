# %% [markdown]
# # Challenges: Python Variables
#
# **Taster 1 — Bit by Bit Coding (Term 2)**
#
# Today's challenges test your understanding of `print`, variables, data types, `input()`, and arithmetic.
#
# **Difficulty levels:** ⭐ Beginner · ⭐⭐ Intermediate · ⭐⭐⭐ Advanced

# %% [markdown]
# ## Part 1: Micro-challenges 🔍 (Individual Practice)

# %% [markdown]
# ### Micro-challenge 1: The Character Card
#
# **Difficulty:** ⭐
#
# Create variables for a game character: `name` (str), `level` (int), `health` (float), and `is_alive` (bool). Print a formatted character card using `print()`.

# %%
# write code here

# %% [markdown]
# ### Micro-challenge 2: The Potion Shop
#
# **Difficulty:** ⭐⭐
#
# Ask the user how many potions they want (`input()`) and convert it to an int. Each potion costs 15 gold. Calculate and print the total cost. Then implement 'buy 3 get 1 free' using `//` and `%`.

# %%
# write code here

# %% [markdown]
# ### Micro-challenge 3: The Tip Calculator
#
# **Difficulty:** ⭐⭐⭐
#
# Ask for a bill amount and a tip percentage. Calculate the tip and the grand total. Round to 2 decimal places and print a nice receipt. *Bonus:* split the bill among a number of people.

# %%
# write code here

# %% [markdown]
# ---
#
# # 🤝 Group Activity
#
# **The Potion Shop**
#
# In pairs, build a mini potion-shop checkout. One person writes the part that asks the customer how many potions they want (using `input()` and `int()`), the other writes the part that calculates the total price (each potion costs 15 gold) and prints a receipt. Combine your code into one program and test it together.

# %%
# write code here

# %% [markdown]
# ---
#
# # 🏠 Homework
#
# *Take these home and attempt them before the next session. Difficulty markers are shown for each exercise.*

# %% [markdown]
# ## Fix-it 🔨 ⭐
#
# This code should print the user's age doubled, but it prints the age twice as text instead of doing math. Find and fix the bug.

# %%
age = input("Enter your age: ")
print("Double your age is:", age * 2)

# %% [markdown]
# ## Predict 🔮 ⭐
#
# Don't run this yet! Write down what you think is printed, then check.

# %%
a = "5"
b = 10
print(a + str(b))
print(int(a) + b)
# Prediction:

# %% [markdown]
# ## Fill-in-the-blanks ✏️ ⭐⭐
#
# Complete the code to ask for a price and quantity, then print the total.

# %%
price = _______(input("Price per item: "))
qty = _______(input("Quantity: "))
total = price _______ qty
print("Total: $", total)

# %% [markdown]
# ---
#
# # 📊 Differentiated Practice
#
# Choose the level that challenges you most — try to work your way up!

# %% [markdown]
# ## Beginner ⭐
#
# Create variables for your name, age, and favourite food. Print a sentence using all three.

# %%
# write code here

# %% [markdown]
# ## Intermediate ⭐⭐
#
# Ask the user for two numbers using `input()`, convert them, and print their sum, difference, product, and quotient.

# %% [markdown]
# > 💡 *Hint:* Don't forget `int()` or `float()` — `input()` always returns a string!

# %%
# write code here

# %% [markdown]
# ## Advanced ⭐⭐⭐
#
# Ask the user for a number of seconds. Convert and print it as hours, minutes, and seconds (e.g. 3661 -> 1h 1m 1s) using `//` and `%`.

# %% [markdown]
# > 💡 *Hint:* 3600 seconds in an hour, 60 in a minute.

# %%
# write code here

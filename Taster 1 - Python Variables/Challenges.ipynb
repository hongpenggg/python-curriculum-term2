# %% [markdown]
# # Challenges: Python Variables
#
# **Taster 1 - Bit by Bit Coding Term 2**
#
# Today's challenges test your understanding of variables, print, input, and arithmetic.
#
# Difficulty levels: ⭐ (Beginner) | ⭐⭐ (Intermediate) | ⭐⭐⭐ (Advanced)
#
# ---

# %%
import random

# write code here

# You can make use of random.randint()

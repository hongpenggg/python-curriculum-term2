# %% [markdown]
# # Challenges: Application Session
#
# **Taster 4 - Bit by Bit Coding Term 2**
#
# Today's challenges combine everything you've learned in Tasters 1-3: variables, control flow, and loops.
#
# Difficulty levels: ⭐ (Beginner) | ⭐⭐ (Intermediate) | ⭐⭐⭐ (Advanced)
#
# ---

# %% [markdown]
# ## Choose Your Challenge
#
# Pick ONE of the three projects below. Start with the basic version, then add features from the "Level Up" section if you finish early.
#
# ---

# %% [markdown]
# ### ⭐ Challenge 1: Custom Quiz Game
#
# Build a quiz game that asks 5 questions and tracks the player's score.
#
# **Requirements:**
# - Store at least 5 questions and answers
# - Use a loop to ask each question
# - Use if/else to check answers
# - Track and display the final score
#
# **Level Up ⭐⭐:** Add different messages based on score (Perfect/Good/Keep practising)
#
# **Level Up ⭐⭐⭐:** Add a 'play again' feature using a while loop

# %%
# Write your quiz game here!
# Hint: Start by storing your questions in a list of tuples:
# questions = [("Question?", "Answer"), ...]
# Then loop through and ask each one

# %% [markdown]
# ### ⭐⭐ Challenge 2: Number Guessing Game
#
# The computer picks a random number 1-100. The player guesses until they get it right.
#
# **Requirements:**
# - Use `import random` and `random.randint(1, 100)` to generate the number
# - Use a while loop to keep asking for guesses
# - Tell the player 'Higher!' or 'Lower!' after each wrong guess
# - Count how many guesses it took
#
# **Level Up ⭐⭐⭐:** Add a maximum of 7 guesses. If they run out, they lose!

# %%
# Write your number guessing game here!
import random

# Generate a random number
secret = random.randint(1, 100)
# Your code here...

# %% [markdown]
# ### ⭐⭐ Challenge 3: Interactive Calculator
#
# Build a calculator that keeps running until the user types 'quit'.
#
# **Requirements:**
# - Ask the user for two numbers and an operation (+, -, *, /)
# - Perform the calculation and display the result
# - Use a while loop to keep the calculator running
# - Handle division by zero gracefully (don't crash!)
#
# **Level Up ⭐⭐⭐:** Add 'power' (^) and 'modulo' (%) operations. Add a history feature that shows all previous calculations.

# %%
# Write your calculator here!

# %% [markdown]
# ---
#
# ## Homework
#
# Complete whichever challenge you started in class. Add at least one feature from the "Level Up" section.
#
# ### Predict! 🔮
# What does this code print? Write your answer, then run it to check:

# %%
total = 0
for i in range(1, 6):
    total += i
print(total)
# Your prediction: ___
# Actual: ___

# %% [markdown]
# ### Fix-it! 🔨
# This quiz code has 2 bugs. Find and fix them:

# %%
# Bug 1: something is wrong with the comparison
# Bug 2: the score isn't being tracked correctly
score = 0
answer = input("What is 2+2? ")
if answer = 4:
    print("Correct!")
    score + 1
else:
    print("Wrong!")
print(f"Score: {score}")

# %% [markdown]
# ### Be Creative! 💡
# Add a new feature to your project. Ideas:
# - Add a timer to see how fast the player can answer
# - Add a high score system (save the best score in a variable)
# - Add sound effects (using print statements like 'BEEP!')
# - Add a story/narrative to your quiz

# %%
# Add your creative feature here!

# %% [markdown]
# ---
#
# ## Further Reading
#
# - [w3schools.com/python/](https://www.w3schools.com/python/) - Full Python tutorial
# - [programiz.com/python-programming](https://www.programiz.com/python-programming) - Comprehensive guide
# - [realpython.com/python-projects/](https://realpython.com/intermediate-python-project-ideas/) - Project ideas

# %% [markdown]
# ---
#
# # 🤝 Group Activity
#
# **Extend the Quest**
#
# In pairs, extend the mini-quest above. One partner adds a shop where the player can spend gold to buy a potion (restores health). The other adds a random enemy encounter each turn. Combine both features and play-test each other's game.

# %%
# write code here

# %% [markdown]
# ---
#
# # 📊 Differentiated Practice
#
# Choose the level that challenges you most — try to work your way up!

# %% [markdown]
# ## Beginner ⭐
#
# Add a 'rest' command to the quest that restores 10 health but costs 5 gold.

# %%
# write code here

# %% [markdown]
# ## Intermediate ⭐⭐
#
# Add a second room with a puzzle the player must solve to win.

# %%
# write code here

# %% [markdown]
# ## Advanced ⭐⭐⭐
#
# Add an inventory system: the player can find and use items that change the outcome of encounters.

# %%
# write code here

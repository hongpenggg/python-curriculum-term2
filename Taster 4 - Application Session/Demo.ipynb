# %% [markdown]
# # 🗺️ Mini Quest: The Dragon's Lair
#
# **Taster 4 — Application Session**
#
# In this guided mini-project you will combine everything from the first three tasters — **variables**, **control flow**, and **loops** — to build a playable text adventure.

# %% [markdown]
# ## 🎯 Learning Objectives
#
# - Combine variables, control flow, and loops in a single mini-project.
# - Use `input()` to drive an interactive, menu-driven program.
# - Keep program state (health, score, inventory) across a game loop.
# - Apply `if/elif/else` and `while` loops together to build a playable text game.

# %% [markdown]
# **Difficulty levels:** ⭐ Beginner · ⭐⭐ Intermediate · ⭐⭐⭐ Advanced

# %% [markdown]
# ## 🎯 The Goal
#
# You are an adventurer entering the Dragon's Lair. You have limited health and gold. Each turn you choose an action, and the outcome depends on your stats and your choices. Survive long enough, find the treasure, and escape!
#
# By the end you will have a small, complete, runnable game.

# %% [markdown]
# ## Part 0: Set Up the Player's State
#
# First we need variables to track the player. We use a **dictionary** so all the stats live in one place.
#
# **Difficulty:** ⭐

# %%
player = {
    'name': '',
    'health': 100,
    'gold': 50,
    'has_key': False,
    'has_treasure': False,
}

# %% [markdown]
# ## Part 1: Welcome the Player (Input & Variables)
#
# Ask the player for their name and store it in the dictionary. Print a welcome message using an f-string.
#
# **Difficulty:** ⭐

# %%
# write code here
# player['name'] = input(...)
# print a welcome using an f-string

# %% [markdown]
# ## Part 2: The Main Game Loop (Loops)
#
# Now wrap everything in a `while True` loop. Each iteration is one turn. Show the player's stats and a menu of actions. The loop keeps running until the player quits, dies, or wins.
#
# **Difficulty:** ⭐⭐

# %%
def show_status(p):
    print(f"\n--- {p['name']} | HP: {p['health']} | Gold: {p['gold']} | Key: {p['has_key']} | Treasure: {p['has_treasure']} ---")

# write your game loop here

# %% [markdown]
# ## Part 3: Make Decisions (Control Flow)
#
# Inside the loop, use `if` / `elif` / `else` to handle the player's choice. For example:
#
# - **Explore**: small chance to find gold or lose health.
# - **Search for the key**: 50% chance to find the key.
# - **Open the door**: only works if the player has the key.
# - **Rest**: restore health but costs gold.
# - **Quit**: break out of the loop.
#
# **Difficulty:** ⭐⭐⭐

# %%
# write code here
# while True:
#     show_status(player)
#     action = input("Choose: explore / search / open / rest / quit > ")
#     if action == 'explore':
#         ...

# %% [markdown]
# ## Part 4: Winning and Losing
#
# Add the win condition: the player wins if they open the door **and** have the treasure. They lose if `health` drops to 0 or below. Use `break` to exit the loop in both cases.
#
# **Difficulty:** ⭐⭐⭐

# %%
# write code here

# %% [markdown]
# ## Part 5: Put It All Together
#
# Combine all your parts into one runnable cell. Play-test it, then swap with a partner and play theirs!
#
# **Difficulty:** ⭐⭐⭐

# %%
# paste your full game here and run it

# %% [markdown]
# ## ✅ Self-Check
#
# - [ ] The game uses **variables** to track state (health, gold, key, treasure).
# - [ ] The game uses **`if`/`elif`/`else`** to handle each action.
# - [ ] The game uses a **`while` loop** so the player can take multiple turns.
# - [ ] The game has a clear **win** and **lose** condition.
# - [ ] The game uses `input()` to read the player's choices.

# %% [markdown]
# ---
#
# ## 📚 Further Reading
#
# Want to go deeper? Check these out:
#
# - [Python Conditions - w3schools](https://www.w3schools.com/python/python_conditions.asp)
# - [Python While Loops - w3schools](https://www.w3schools.com/python/python_while_loops.asp)
# - [Build a Text-Based Game - Real Python](https://realpython.com/python-command-line-game/)

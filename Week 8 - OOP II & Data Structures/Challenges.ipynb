# %% [markdown]
# # Challenges: OOP II & Data Structures
#
# **Week 8 — Bit by Bit Coding (Term 2)**
#
# Today's challenges test inheritance, method overriding, and basic data structures (stacks, queues, linked lists).
#
# **Difficulty levels:** ⭐ Beginner · ⭐⭐ Intermediate · ⭐⭐⭐ Advanced

# %% [markdown]
# ## Part 1: Inheritance & Polymorphism 🔍 (Individual Practice)

# %% [markdown]
# ### Task 1: Animal Hierarchy
#
# **Difficulty:** ⭐
#
# Create a base `Animal` class with a `name` attribute and a `speak()` method that prints a generic sound. Then create `Dog` and `Cat` subclasses that **override** `speak()`.

# %%
# write code here

# %% [markdown]
# ### Task 2: Using `super()`
#
# **Difficulty:** ⭐⭐
#
# Create a `Vehicle` base class (attributes: `brand`, `speed`) and a `Car` subclass that adds `wheels` and calls `super().__init__()` to set `brand` and `speed`.

# %%
# write code here

# %% [markdown]
# ## Part 2: Data Structures 🧱 (Individual Practice)

# %% [markdown]
# ### Task 3: Stack (LIFO)
#
# **Difficulty:** ⭐⭐
#
# Implement a `Stack` class using a Python list. Add `push(x)`, `pop()`, `peek()`, and `is_empty()`. Use it to reverse a string: push each char, then pop them all.

# %%
class Stack:
    def __init__(self):
        self.items = []
    # write code here

# %% [markdown]
# ### Task 4: Queue (FIFO)
#
# **Difficulty:** ⭐⭐
#
# Implement a `Queue` class with `enqueue(x)` and `dequeue()`. Model a printer queue: enqueue 3 print jobs, then dequeue and print each one in order.

# %%
class Queue:
    def __init__(self):
        self.items = []
    # write code here

# %% [markdown]
# ### Task 5: Linked List
#
# **Difficulty:** ⭐⭐⭐
#
# Implement a singly `LinkedList` with a `Node` class (`value`, `next`). Add `insert_at_head(value)` and `display()` that prints all values. Then add a `size()` method.

# %%
class Node:
    def __init__(self, value, next_node=None):
        # write code here
        pass

class LinkedList:
    def __init__(self):
        self.head = None
    # write code here

# %% [markdown]
# ---
#
# # 🤝 Group Activity
#
# **The Undo Stack & Printer Queue**
#
# In pairs, build two data structures. Partner A makes a `Stack` class (push/pop) to implement an 'undo' feature. Partner B makes a `Queue` class (enqueue/dequeue) to model a printer queue. Discuss which is LIFO vs FIFO and why each fits its job.

# %%
class Stack:
    def __init__(self):
        self.items = []
    # add push and pop here

# %% [markdown]
# ---
#
# # 🏠 Homework
#
# *Take these home and attempt them before the next session. Difficulty markers are shown for each exercise.*

# %% [markdown]
# ## Fix-it 🔨 ⭐
#
# This subclass doesn't call the parent constructor, so `name` is missing. Fix it with `super()`.

# %%
class Animal:
    def __init__(self, name):
        self.name = name

class Dog(Animal):
    def __init__(self, breed):
        self.breed = breed

d = Dog('Labrador')
print(d.name)

# %% [markdown]
# ## Predict 🔮 ⭐⭐
#
# What is printed by this stack?

# %%
s = []
s.append(1)
s.append(2)
s.pop()
print(s)
# Prediction:

# %% [markdown]
# ## Fill-in-the-blanks ✏️ ⭐⭐
#
# Complete the queue's dequeue method.

# %%
class Queue:
    def __init__(self):
        self.items = []
    def enqueue(self, x):
        self.items.append(x)
    def dequeue(self):
        return self.items._______(0)

# %% [markdown]
# ---
#
# # 📊 Differentiated Practice
#
# Choose the level that challenges you most — try to work your way up!

# %% [markdown]
# ## Beginner ⭐
#
# Create an `Animal` base class with a `speak()` method that prints a generic sound. Then make a `Dog` subclass that overrides `speak()` to print 'Woof!'.

# %%
class Animal:
    def speak(self):
        pass

# %% [markdown]
# ## Intermediate ⭐⭐
#
# Implement a `Stack` class with `push`, `pop`, and `is_empty` using a Python list internally.

# %% [markdown]
# > 💡 *Hint:* `list.append` and `list.pop` are all you need.

# %%
class Stack:
    def __init__(self):
        self.items = []
    # write code here

# %% [markdown]
# ## Advanced ⭐⭐⭐
#
# Implement a singly `LinkedList` with a `Node` class. Add `insert_at_head(value)` and `display()` methods.

# %%
class Node:
    def __init__(self, value, next=None):
        pass

class LinkedList:
    def __init__(self):
        self.head = None

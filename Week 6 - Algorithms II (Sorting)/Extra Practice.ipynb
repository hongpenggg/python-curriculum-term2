# %% [markdown]
# # Welcome to Extra Practices!
#
# Do note that some questions here require concepts we didn't teach, so feel free to do your **own** research!
#
# *Adapted from VJC Computing*

# %% [markdown]
# **Difficulty levels:** ⭐ Beginner · ⭐⭐ Intermediate · ⭐⭐⭐ Advanced

# %% [markdown]
# ---
#
# Q1. Bubble Sort ⭐
#
# Implement `bubble_sort(arr)` that sorts a list in ascending order. Add a `swaps` counter and print it.

# %% [markdown]
# > 💡 *Hint:* Compare adjacent pairs and swap if out of order; repeat for `len(arr)` passes.

# %%
def bubble_sort(arr):
    # write code here
    pass

# %% [markdown]
# ---
#
# Q2. Selection Sort ⭐⭐
#
# Implement `selection_sort(arr)`. Find the minimum in the unsorted part and swap it into place.

# %% [markdown]
# > 💡 *Hint:* Track `min_idx` across the inner loop, then swap once per outer pass.

# %%
def selection_sort(arr):
    # write code here
    pass

# %% [markdown]
# ---
#
# Q3. Insertion Sort ⭐⭐
#
# Implement `insertion_sort(arr)`. Build the sorted portion one item at a time by inserting each new item in the right place.

# %% [markdown]
# > 💡 *Hint:* Shift larger elements right until you find the insertion spot.

# %%
def insertion_sort(arr):
    # write code here
    pass

# %% [markdown]
# ---
#
# Q4. Sort Stability ⭐⭐⭐
#
# Sort a list of `(name, score)` tuples by score descending. Then explain in a comment: which of your sorts is *stable*, and why that matters for a leaderboard with ties?

# %% [markdown]
# > 💡 *Hint:* A stable sort keeps equal elements in their original order.

# %%
scores = [('Alex', 50), ('Bo', 90), ('Cara', 50), ('Dan', 70)]
# write code here

# %% [markdown]
# # Welcome to Extra Practices!
#
# Do note that some questions here require concepts we didn't teach, so feel free to do your **own** research!

# %% [markdown]
# Create a `BankAccount` class where the balance is private. Users should only be able to deposit, withdraw, and check balance through defined methods. Withdrawals beyond the available balance should be rejected.

# %%
class BankAccount:
    def __init__(self, owner, initial_balance):
        # Make balance private
        pass

    def deposit(self, amount):
        pass

    def withdraw(self, amount):
        pass

    def get_balance(self):
        pass

# %%
# Test your code
acc = BankAccount("Alice", 500)
acc.deposit(200)       # balance: 700
acc.withdraw(100)      # balance: 600
acc.withdraw(9999)     # "Insufficient funds"
print(acc.get_balance())

# %% [markdown]
# Create a base Animal class with name and sound attributes and a `speak()` method. Then create `Dog` and `Cat` subclasses. Dogs should also have a `fetch()` method and Cats a `purr()` method. All animals should inherit `speak()`.

# %%
# Create an Animal class
# Add a speak() method that prints "I am a talking animal, my name is {name}. {sound}!"


# Create a Dog class that inherits from Animal
# Add a fetch(item) method that prints "<name> fetched <item>!"


# Create a Cat class that inherits from Animal
# Add a purr() method that prints "Purr... I am <name>"

# %%
d = Dog("Rex")
d.speak()    # Rex says Woof
d.fetch("ball")

c = Cat("Luna")
c.speak()    # Luna says Meow
c.purr()

# %% [markdown]
# Build a Notification base class with a `send(message) `method. Create Email, SMS, and PushNotification subclasses that each implement `send()` differently. Write a `notify_all(notifiers, message)` function that sends the message through every channel.

# %%
# Keep Notification class unchanged
class Notification:
    def send(self, message):
        raise NotImplementedError

# Create an Email class that inherits from Notification
# This class should have an address attribute
# Implement a send(message) method that prints "<message> emailed to <address>"

# Create an SMS class that inherits from Notification
# This class should have a number attribute
# Implement a send(message) method that prints "<message> SMS to <number>"

# Create an PushNotification class that inherits from Notification
# This class should have a device_id attribute
# Implement a send(message) method that prints "<message> pushed to <device_id>"


def notify_all(notifiers, message):
    pass

# %%
# Test your code!
channels = [
    Email("user@example.com"),
    SMS("+65 9123 4567"),
    PushNotification("device-abc")
]
notify_all(channels, "Your order has shipped!")

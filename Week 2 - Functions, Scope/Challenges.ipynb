# %% [markdown]
# # Challenges: Functions and Scope
#
# **Week 2 - Bit by Bit Coding Term 2**
#
# Today's challenges test your understanding of functions, parameters, return values, and scope.
#
# Difficulty levels: ⭐ (Beginner) | ⭐⭐ (Intermediate) | ⭐⭐⭐ (Advanced)
#
# ---

# %% [markdown]
# You need to create a tracking system for a game that can track and update the health of a player.

# %% [markdown]
# # Requirements
# 1. `take_damage(health, damage)`, this function takes the current health of the plater and subtracts the damage value from the health value. Return the updated health. *MAKE SURE THE FUNCTION DOES NOT RETURN NEGATIVE VALUES*
# 2. `level_up(experience, level, level_up_threshold)`, this function updates the level whenever the experience exceeds the *level_up_threshold*. Return the updated level
# 3. `apply_poison(health, poison_damage, turns)` recursively applies poison damage each turn until either turns run out, or health falls below 0. Return the health final health.
# 4. `draw_health_bar(health, max_health)` this function uses the *turtle* library to draw a statis health bar for the player.
#
# #Preset values
# - `level_up_threshold = 150`
# - `if health > 50%` health bar should be green
# - `if health > 20%` health bar should be orange
# - `if health < 20%` health bar should be red
#
# *Hint: You can draw two rectangles to represent the health bar!*

# %%
# write code here

# %% [markdown]
# #Homework

# %% [markdown]
# **Difficulty:** ⭐
#
# ## Fix-it! 🔨
# The following code has many errors, can you spot and fix them?

# %%
numbers = [3, 7, 2, 12, 5]
def find_largest(nums):
    largest = 0

    for n in nums:
        if n > largest:
            largest = n

def show_result():
    find_largest(numbers)
    print("Largest number:", largest)

show_result()

# %% [markdown]
# **Difficulty:** ⭐
#
# # Predict! 🔮

# %% [markdown]
# Don't run this code in a cell yet! Look at the code and write down what you think the output will be for each print statement.

# %%
def add(a, b):
    result = a + b
    print("Inside function:", result)
    return result

value = add(3, 4)
print("Outside function:", value)

# Prediction:

# %%
def f1(x):
    return x * 2

def f2(num):
    num = f1(num)
    num = num + 3
    return num

print(f2(f1(5)))

# Prediction:

# %%
x = 10

def change():
    x = 5
    print("Inside:", x)

change()
print("Outside:", x)

# Prediction:

# %% [markdown]
# **Difficulty:** ⭐
#
# ## Fill-in-the-blanks! ✏️

# %%
# The final function takes a list and returns how many numbers in the list are even

def is_even(n):
    _______ n % _______ == 0

numbers = [3, 6, 8, 11]

def counter______
    count = 0

    for n in numbers:
        if _______(n):
            count = count + 1

    return _________

print("Even numbers:", counter(numbers))

# %% [markdown]
# ---
#
# # 🤝 Group Activity
#
# **The Stats Toolkit**
#
# In pairs, build a small stats toolkit. Write functions `mean(nums)`, `max_val(nums)`, and `sum_evens(nums)` (using `*args` to accept any number of values). One partner writes `mean` and `max_val`, the other writes `sum_evens`. Combine into one module and test with shared data.

# %%
def mean(*nums):
    # write code here
    pass

# %% [markdown]
# ---
#
# # 📊 Differentiated Practice
#
# Choose the level that challenges you most — try to work your way up!

# %% [markdown]
# ## Beginner ⭐
#
# Write a function `greet(name)` that returns `'Hello, ' + name + '!'`. Call it and print the result.

# %%
def greet(name):
    # write code here
    pass

# %% [markdown]
# ## Intermediate ⭐⭐
#
# Write a function `apply_twice(f, x)` that calls function `f` twice on `x` and returns the result. Test it with a `square` function.

# %% [markdown]
# > 💡 *Hint:* Return `f(f(x))`.

# %%
def apply_twice(f, x):
    # write code here
    pass

# %% [markdown]
# ## Advanced ⭐⭐⭐
#
# Write a function `make_multiplier(n)` that RETURNS a function which multiplies its input by `n`. Then create `double = make_multiplier(2)` and `triple = make_multiplier(3)` and test them.

# %%
def make_multiplier(n):
    # write code here
    pass

# %% [markdown]
# **Difficulty:** ⭐⭐
#
# # Collaborative Challenge 🚀: "The Ultimate Loot Tracker"

# %% [markdown]
# **Difficulty levels:** ⭐ Beginner · ⭐⭐ Intermediate · ⭐⭐⭐ Advanced

# %% [markdown]
# Your team is building the inventory system for a new multiplayer RPG. You need to create a system that lets a player view their inventory, buy new items, and sell items to a shop. Run the cell below to get started!

# %%
# Initial character data
player_stats = {
    "username": "Hero_123",
    "gold": 70,
    "inventory": []
}

# The shop's price list
item_prices = {
    "Shield": 50,
    "Bread": 5,
    "Rusty Sword": 20,
    "Health Potion": 30
}

# %% [markdown]
# **Difficulty:** ⭐⭐
#
# ## 🛠️ The Mission Requirements
#
# Your code must perform the following tasks in a loop so the player can keep performing actions until they type `"Quit"`:
# 1. **Display Status**: Use a loop to print every item in the inventory list and show the current gold balance.
# 2. **User Input**: Ask the player what they want to do: `"Buy"`, `"Sell"`, or `"Quit"`.
# 3. **The "Buy" Feature**: Ask the user for the name of the item they want to buy. If the player:
#   - Has enough gold to buy the item
#   - Does not already own the item (item is not in `inventory`)
#   - The item exists in `item_prices`
#
# Then, add the item to the players `inventory` and decrease the player's `gold` by the price of the item.
#
# *Hint: Find a way to check if the item exists in the item_prices dictionary before adding it*
#
# 4. **The "Sell" Feature**: If they have it in their `inventory`, remove it from the list. Find the price of that item in `item_prices` and add that amount to the `gold` value in the `player_stats` dictionary.
#
# *Hint: How do you delete a specific item from a list by its name?*
#
# 6. **Exit Strategy**: If they type `"Quit"`, break the loop and print a "Game Over" message.
#
# *Note: The player initially starts off with an empty inventory*

# %%
# write code here

# %% [markdown]
# **Difficulty:** ⭐⭐⭐
#
# ### **Bonus Task**
# What happens if the user wants to be funny and input some other string instead of `"Buy"`, `"Sell"`, or `"Quit"`? Does your program crash?
# Amend your code such that your program doesn't crash when an invalid input is entered. Display a message reminding the user to only enter `"Buy"`, `"Sell"`, or `"Quit"`.

# %% [markdown]
# # Homework

# %% [markdown]
# **Difficulty:** ⭐
#
# ## Fix-it! 🔨
# The following code has many errors, can you spot and fix them?

# %%
# The Goal: Add a fruit, remove an old one, and update the user's loyalty points.

fruits = ["Apple", "Pear", "Orange"]
user_stats = {"name": "Ishowspeed", "loyalty_points": 10}

# 1. Try to add "Durian"
fruits.append["Durian"]

# 2. Try to remove "Orange"
fruits.delete("Orange")

# 3. Accessing Ishowspeed's loyalty points
print("Current Points: " + user_stats(loyalty_points))

# 4. Give Ishowspeed more loyalty points
user_stats["loyalty_points"] = "11" + 1

# 5. Slicing the first two fruits
top_fruits = fruits[1:2]

# %% [markdown]
# **Difficulty:** ⭐
#
# ## Predict! 🔮

# %% [markdown]
# Don't run this code in a cell yet! Look at the code and write down what you think the output will be for each print statement.

# %%
items = ["Sword", "Shield", "Potion", "Map", "Key"]
print(items[1:6])
# Prediction:

# %%
scores = [150, 220, 300, 450]
print(scores[-5])
# Prediction:

# %%
vault = ["Gold", ["Diamond", ["Emerald"]], "Silver"]
print(vault[1][1][0])
# Prediction:

# %% [markdown]
# **Difficulty:** ⭐
#
# ## Fill-in-the-blanks! ✏️

# %% [markdown]
# **Difficulty:** ⭐⭐
#
# ## Be Creative! 💡
# Complete this script to create a "Character Profile Generator." Use the hints in the comments to choose the right list or dictionary methods.

# %%
# Create a dictionary for a new character
hero = {
    "name": "Link",
    "hearts": 3,
    "inventory": ["Stick", "Shield"]
}

# 1. The player finds a 'Master Sword'. Add it to the START of the list.
hero["inventory"]._______("Master Sword")

# 2. Check if the player is 'Link' using the key.
if hero[_______] == "Link":
    print("Welcome back, Hero of Time!")

# 3. The player takes damage! Subtract 1 from 'hearts'.
hero["hearts"] = _______

# 4. Use a loop to print every item in the inventory.
for item in hero[_______]:
    print("Item found: " + item)

# 5. Find how many items are in the inventory.
total_items = _______(hero["inventory"])
print(f"You are carrying {total_items} items.")

# %% [markdown]
# **Difficulty:** ⭐⭐⭐
#
# ### Fibonacci Sequence Generator *Improved*
#
# #### **Background**
# The Fibonacci sequence is a series of numbers where each number is the sum of the two preceding ones, usually starting with 0 and 1.The mathematical definition is:$$F_n = F_{n-1} + F_{n-2}$$
#
# So,
# $$F(0)=0$$
# $$F(1)=1$$
# $$F(2)=F(1)+F(0)=1$$
# $$F(3)=F(2)+F(1)=2$$
#
# #### **Task**
# Remember the Fibonacci Sequence Generator we made last week? Lets optimise it!
#
# 1. We can simplify our loop! Instead of keeping track of two separate variables, we can pull the values we need **directly** from the list we're building!
#
# 2. Currently, we're just printing each number individually, which is a bit inefficient. This time, let's modify the logic to store the sequence in a **list** first, then output the entire result with a **single** print statement.

# %%
# write code here

# %% [markdown]
# ---
#
# # 🤝 Group Activity
#
# **The Class Roster**
#
# In pairs, build a class roster manager. Store students in a list of dictionaries (each with `name`, `score`). Implement: add student, remove student, and show the class average. One partner handles the list operations, the other handles the dictionary access. Combine and test.

# %%
# write code here

# %% [markdown]
# ---
#
# # 📊 Differentiated Practice
#
# Choose the level that challenges you most — try to work your way up!

# %% [markdown]
# ## Beginner ⭐
#
# Create a list of 5 favourite foods. Print the first and last item using indexing.

# %%
# write code here

# %% [markdown]
# ## Intermediate ⭐⭐
#
# Given `nums = [3, 1, 4, 1, 5, 9, 2, 6]`, use a list comprehension to create a new list of only the even numbers.

# %% [markdown]
# > 💡 *Hint:* `[n for n in nums if n % 2 == 0]`

# %%
nums = [3, 1, 4, 1, 5, 9, 2, 6]
# write code here

# %% [markdown]
# ## Advanced ⭐⭐⭐
#
# Build a dictionary mapping student names to a list of marks. Use a dictionary comprehension to create a new dict of names to their average mark.

# %%
grades = {'Alex': [70, 80], 'Bo': [90, 60], 'Cara': [100, 95]}
# write code here

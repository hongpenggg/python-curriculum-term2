# %% [markdown]
# # What are Data Structures?
#
# Data structures are specialised formats for organizing, storing, processing, and retrieving data so it can be used **efficiently**.
# Lists and Dictionaries are data structures that you will most commonly use in Python!

# %% [markdown]
# # Lists
# Think of a **Python list** as your digital inventory. Instead of having a bunch of loose items (variables) floating around, you put them all into one organised container.

# %% [markdown]
# ## What is a List?
#
# - **It’s a Container**: It holds multiple items under one name.
# - **Mixed Bag**: You can throw strings, numbers, or even other lists inside one list.
# - **Ordered**: Python remembers exactly what order you put things in.

# %% [markdown]
# In Python, lists are defined by **square brackets** `[]`, and items are separated by commas.
# Run the cell below to set up your starting games.

# %%
# Keeping track of games I like
games = ["Minecraft", "Fortnite", "Roblox", "Valorant", 99, "Valorant"]
print("My Library:", games)
# Out:
# My Library: ['Minecraft', 'Fortnite', 'Roblox', 'Valorant', 99, 'Valorant']

# %% [markdown]
# ## The "Address" System (Indexing)
#
# This is where it gets a little quirky. Computers don't start counting at 1; they start at **0**.
#
#
# <table>
#   <tr>
#     <th>Item</th>
#     <td>Minecraft</td>
#     <td>Fortnite</td>
#     <td>Roblox</td>
#     <td>Valorant</td>
#   </tr>
#   <tr>
#     <th>Index</th>
#     <td>0</td>
#     <td>1</td>
#     <td>2</td>
#     <td>3</td>
#   </tr>
# </table>
#
#
# Now, let's try retrieving each item in the list by index!
#
# *Pro Tip: Use -1 to grab the very last item in the list quickly!*

# %%
games[-2]
# Out:
# 'Roblox'

# %% [markdown]
# You can actually index strings too, try it out!

# %%
food = "rice"
food[1]
# Out:
# 'i'

# %% [markdown]
# ## Scanning Your Inventory
#
# We can also use a `for` loop to look at every game in our library by:
# 1. Looping through the list itself
# 2. Looping through the indexes of the list items

# %%
for i in range(0, len(games)):
  print(games[i])
# Out:
# Minecraft
# ['Clash Royale', 'Candy Crush']
# Roblox
# Valorant

# %%
for i in games:
  print(i)
# Out:
# Minecraft
# ['Clash Royale', 'Candy Crush']
# Roblox
# Valorant

# %%
for (x,y) in enumerate(games):
  print(x,y)
# Out:
# 0 Minecraft
# 1 Fortnite
# 2 Roblox
# 3 Valorant
# 4 99
# 5 Valorant

# %% [markdown]
# ## Slicing: Select Your Loadout
#
# Slicing lets you grab a specific "sub-list" (a piece of the original).
#
# The syntax is: `list[start : stop: step]`
# - The start index is included.
# - The stop index is excluded (Python stops right before this index).
# - The step size, specifying the interval between elements.
#
# *Try leaving the start, stop and step empty to see what happens!*

# %%
games1 = games[0:2]
games1
# Out:
# ['Minecraft', 'Fortnite']

# %%
games1 = games[2:4]
games1
# Out:
# ['Roblox', 'Valorant']

# %%
games1 = games[::2]
games1
# Out:
# ['Minecraft', 'Roblox', 99]

# %%
games2 = games[::-1]
games2
# Out:
# ['Valorant', 99, 'Valorant', 'Roblox', 'Fortnite', 'Minecraft']

# %% [markdown]
# ---
#
# # Micro-challenge 1 🔍: The Slicing Scout (Slicing)
#
# You need to organise your gear for a mission.

# %%
# run this cell
inventory = ["Bow", "Arrow", "Torch", "Food", "Rope", "Tent", "Stone"]

# %% [markdown]
# 1. Create a new list called `combat_gear` that contains only the first two items using a slice.

# %%
# write code here
combat_gear = inventory[0:2]
combat_gear
# Out:
# ['Bow', 'Arrow']

# %% [markdown]
# 2. Create a new list called `camping_gear` that contains items from index `3` to index `5` (inclusive).

# %%
# write code here
camping_gear = inventory[3:6]
camping_gear
# Out:
# ['Food', 'Rope', 'Tent']

# %% [markdown]
# 3. Print both lists to make sure you didn't accidentally pack the "Stone"!

# %%
# write code here
print(combat_gear)
print(camping_gear)
# Out:
# ['Bow', 'Arrow']
# ['Food', 'Rope', 'Tent']

# %% [markdown]
# **Bonus Task**: Using slicing, create and print out a new list that contains every alternate item in your inventory.
#
# Your list should look like this: `['Bow', 'Torch', 'Rope', 'Stone']`

# %%
# write code here
alternate_item = inventory[::2]
alternate_item
# Out:
# ['Bow', 'Torch', 'Rope', 'Stone']

# %%
alternate1 = inventory[::-1]
alternate1
# Out:
# ['Stone', 'Tent', 'Rope', 'Food', 'Torch', 'Arrow', 'Bow']

# %% [markdown]
# ---
# ## Mutability: Upgrade Your Library
#
# Lists are mutable, which is a fancy dev word for "changeable." Unlike some other data types, you can mess with a list after you've created it.
#
# ### ➕ Adding a New Favorite
# I found a new game I like and I want to add it to my list! We use `.append()` to tack something onto the end.

# %%
games.append("Marvel Rivals")
games
# Out:
# ['Minecraft',
#  'Fortnite',
#  'Roblox',
#  'Valorant',
#  99,
#  'Valorant',
#  'Marvel Rivals']

# %% [markdown]
# ### ➖ Deleting the Boring Stuff
# A game got boring and I want to remove it! We can use `.remove()` (by name), `.pop()` (by index), or `del`.

# %%
games.pop(3)
# Out:
# 'Valorant'

# %%
games
# Out:
# ['Minecraft', 'Fortnite', 'Roblox', 99, 'Valorant']

# %%
games.remove('Fortnite')
games
# Out:
# ['Minecraft', 'Roblox', 99, 'Valorant']

# %%
del games[1]
games
# Out:
# ['Minecraft', 99, 'Valorant']

# %% [markdown]
# ### 🔄 Swapping Items
# You can swap one game for another just by pointing to its index.

# %%
games[1]=games[2]
games
# Out:
# ['Minecraft', 'Valorant', 'Valorant']

# %% [markdown]
# ## 🔍 The Search Tool
# What if I want to know whether `"Minecraft"` is still in my list of `games`?

# %%
if "Minecraft" in games:
  print("You still have minecraft installed")
else:
  print("You deleted minecraft :(")
# Out:
# You still have minecraft installed

# %% [markdown]
# ## 📦 Nested Lists
#
# A list can contain other lists! These are called **nested lists**.
# Think of it like a DLC pack or a specific category folder within your library.

# %%
# 'Mobile Games' is a list inside the main list
games = ["Minecraft", ["Clash Royale", "Candy Crush"], "Roblox", "Valorant"]

# %% [markdown]
# We can access items in the nested lists by using **double indexing**!

# %%
games[1][0]
# Out:
# 'Clash Royale'

# %% [markdown]
# ---
# # Micro-challenge 2 🔍: The Loot Drop (Lists)
#
# You just defeated a boss, and it dropped a massive pile of loot.
#
# 1. Create a list called `dropped_items` containing: `"Gold"`, `"Shield"`, `"Health Potion"`, `"Map"`, and `"Old Key"`.

# %%
# write code here
dropped_items = ["Gold", "Shield", "Health Potion", "Map", "Old Key"]
dropped_items
# Out:
# ['Gold', 'Shield', 'Health Potion', 'Map', 'Old Key']

# %% [markdown]
# 2. A thief ran by and stole the first item! 😱 Remove the item at index `0`.

# %%
# write code here
del dropped_items[0]
dropped_items
# Out:
# ['Shield', 'Health Potion', 'Map', 'Old Key']

# %% [markdown]
# 3. You found a secret chest! 🤩 Add `"Diamond Sword"` to the end of your list

# %%
# write code here
dropped_items.append("Diamond Sword")

# %% [markdown]
# 4. Print your final inventory and the total number of items you have.

# %%
# write code here
print(f"The total number of items here is {len(dropped_items)}. The items are: {dropped_items}")
# Out:
# The total number of items here is 5. The items are: ['Shield', 'Health Potion', 'Map', 'Old Key', 'Diamond Sword']

# %%
inventory = ["Torch","Bow", "Arrow" , "Food", "Rope","7huefhefbeufbeu", "Tent", "Stone"]

# %% [markdown]
# ### Sorting Lists

# %%
inventory.sort(key=len)
inventory
# Out:
# ['Bow', 'Food', 'Rope', 'Tent', 'Torch', 'Arrow', 'Stone', '7huefhefbeufbeu']

# %%
inventory.sort(reverse=True)
inventory
# Out:
# ['Torch', 'Tent', 'Stone', 'Rope', 'Food', 'Bow', 'Arrow', '7huefhefbeufbeu']

# %%
new_inventory = sorted(inventory)
new_inventory
# Out:
# ['Arrow', 'Bow', 'Food', 'Rope', 'Stone', 'Tent', 'Torch']

# %%
inventory
# Out:
# ['Bow', 'Arrow', 'Torch', 'Food', 'Rope', 'Tent', 'Stone']

# %% [markdown]
# ---
# ### 🛠️ More Tools
# Want to see every trick a list can do? Check out the [W3Schools List Reference](https://www.w3schools.com/python/python_ref_list.asp).

# %% [markdown]
# ---
#
# # Dictionaries
#
# If a Python list is an ordered junk drawer, a Python dictionary is a labeled locker system.
#
# In a list, you find things by their position (0, 1, 2). In a dictionary, you find things by a specific **Key** (like a name tag) to get a **Value** (the actual data).
#
# Dictionaries use curly braces `{}`. Each entry is a pair: a **key**, a **colon**, and a **value**.

# %%
# A dictionary representing a game character's stats
character = {
    "name": "Zelda",
    "level": 50,
    "item": "Master Sword",
    "is_alive": True
}

# %% [markdown]
# Key features:
# - **Key-Value Pairs**: Every piece of data has a unique label.
# - **Unordered (Technically)**: While modern Python remembers the order you typed them, you don't use numbers to find things; you use the labels.
# - **Unique Keys**: You can't have two "name" tags in the same locker—Python wouldn't know which one to open!

# %% [markdown]
# Imagine you are building an RPG. A list of items is fine, but a dictionary lets you store **details** about those items.
#
# <table>
#   <tr>
#     <th>Key (The Label)</th>
#     <th>Value (The Data)</th>
#   </tr>
#   <tr>
#     <td>"name"</td>
#     <td>"Zelda"</td>
#   </tr>
#   <tr>
#     <td>"level"</td>
#     <td>50</td>
#   </tr>
#   <tr>
#     <td>"item"</td>
#     <td>"Master Sword"</td>
#   </tr>
#   <tr>
#     <td>"is_alive"</td>
#     <td>True</td>
#   </tr>
# </table>
#
#
# To see your health, you don't ask for "item 1"; you just ask for "health".
#
# ## Look Up a Value
# I want to find out whether my character is still alive.

# %%
print(character['is_alive'])
# Out:
# True

# %% [markdown]
# ## Add or Update
# Zelda leveled up, let's update our dictionary to reflect this.

# %%
character['level'] = 51

# %% [markdown]
# ---
# # Micro-challenge 3 🔍: The Blacksmith (Dictionaries)
#
# 1. Create a dictionary called `shield_stats` with the following keys and values:
# - `"material": "Iron"`
# - `"defense": 25`
# - `"broken": False`

# %%
# write code here
shield_stats = {
    'material': 'Iron',
    'defense': 25,
    'broken': False
}

# %% [markdown]
# 2. You took the shield to a blacksmith. Update the `"defense"` value to `40`.
#
# *Alternatively, you could use the `+=` operator to increase defense by `15`*

# %%
# write code here

shield_stats['defense'] = 40

# alternatively shield_stats['defense'] += 15

# %% [markdown]
# 3. The blacksmith added a new feature! 🤩 Add a new key called `"element"` and set it to `"Fire"`.

# %%
# write code here

shield_stats['element'] = 'Fire'

# %% [markdown]
# 4. Print the dictionary to see your upgraded shield.

# %%
# write code here
print(shield_stats)
# Out:
# {'material': 'Iron', 'defense': 40, 'broken': False, 'element': 'Fire'}

# %% [markdown]
# ---
# # Copying Lists and Dictionaries
#
# Ensure you use `.copy` or `copy.deepcopy()` when copying a list or dictionary. You might get unexpected behaviours if you aren't careful!

# %%
import copy

my_lst = [[1], 2, 3, 4]
copy_my_lst = copy.deepcopy(my_lst) # creates a new copy of my_lst

my_lst[0][0] = 2 # modifying my_lst doesn't modify copy_my_lst
print(f'my_lst: {my_lst}')
print(f'copy_my_lst: {copy_my_lst}')
# Out:
# my_lst: [[2], 2, 3, 4]
# copy_my_lst: [[1], 2, 3, 4]

# %%
greet = 'hi'
print(f"Old greet's memory address: {id(greet)}")
greet = greet + 'i'
print(f"New greet's memory address: {id(greet)}") # different memory address - this means strings are immutable
print('----------------------------------------------')
my_lst = [1]
print(f"Old my_lst's memory address: {id(my_lst)}")
my_lst.append(2)
print(f"New my_lst's memory address: {id(my_lst)}") # same memory address - this means that lists are mutable
# Out:
# Old greet's memory address: 11688400
# New greet's memory address: 136908364695904
# ----------------------------------------------
# Old my_lst's memory address: 136908367850816
# New my_lst's memory address: 136908367850816

# %% [markdown]
# # Lists vs. Dictionaries: Which to use?
# - Use a **List** if you have a collection of similar items where the **order** matters (like a leaderboard or a queue of players).
# - Use a **Dictionary** if you have a piece of data that needs a **description** (like a user profile, a contact card, or a game character's attributes).

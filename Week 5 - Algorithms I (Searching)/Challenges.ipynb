# %% [markdown]
# **Difficulty:** ⭐⭐
#
# # Week 5: Searching Micro-challenges
#
# **Week 5 — Bit by Bit Coding (Term 2)**
#
# This notebook combines micro-challenges for individual practice, collaborative pair programming, and homework.

# %% [markdown]
# **Difficulty levels:** ⭐ Beginner · ⭐⭐ Intermediate · ⭐⭐⭐ Advanced

# %% [markdown]
# **Difficulty:** ⭐⭐
#
# ## Part 1: Micro-challenges 🔍 (Individual Practice)
# **Goal:** Build searching algorithms and handle basic data structures.
#
# Imagine you are the administrator of a school, and you have **1000** students. Your job is to tell the principal if a certain student by a certain name exists, and find his/her student ID!<br>
#
# Run the following code

# %%
# Run this cell
# Don't modify anything!

# !pip install faker

print("Yo im faker im the goat")
# Out:
# Collecting faker
#   Downloading faker-40.18.0-py3-none-any.whl.metadata (16 kB)
# Downloading faker-40.18.0-py3-none-any.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 26.6 MB/s eta 0:00:00
# Installing collected packages: faker
# Successfully installed faker-40.18.0
# Yo im faker im the goat

# %%
# Micro-challenge 1: Setting up the Student Database
from faker import Faker
import uuid

fake = Faker()
names = sorted([fake.unique.name() for i in range(100)])

def assign_uuids(namelist):
    """Return a nested list [[name, uuid_str], ...] using UUIDv4 (random)."""
    return [[name, str(uuid.uuid4())] for name in namelist]

namelist = assign_uuids(names)
print(f"Database created with {len(namelist)} students.")
print(f"First 10 names and ids: {namelist[:10]}")
# Out:
# Database created with 100 students.
# First 10 names and ids: [['Alexander Peterson', '0683428d-c787-4acd-a8b0-35433db53bce'], ['Alexandria Espinoza', '25615260-f855-4744-a507-a77b62ac79f6'], ['Amanda Crawford', '86c1c309-e1c8-4120-813c-24b1a89b2108'], ['Amanda Lopez', 'c49c2f8c-2aac-4168-8dd1-63dcd57290bf'], ['Andrew Berry', '42ad6f2c-e9e6-419f-bf3c-a391ad91be3c'], ['Angela Brooks', '1f18cc6f-b075-41be-8a2f-525daa8f9f20'], ['Anthony Nguyen', '6ee5e067-54bf-4813-8713-3c6ff7f66502'], ['April Hansen MD', 'a10c5726-ba68-4542-83bf-0a50d81885d7'], ['April Kent', '3fb72eab-3fd3-426e-aea1-b53faaffe2cf'], ['Ashley Jackson', '3450a01e-b99d-4ab0-b112-f59088bad877']]

# %% [markdown]
# **Difficulty:** ⭐
#
# ### Task 2: Linear Search
# Write a function `student_search` that performs a linear search to find a student's ID by their name.

# %%
def student_search(namelist, target_name):
    # Your code here:
    for ___ in ___:
        # You compare ? with ?:
        if ___ == ___:
            # You can output the position
            # Return, or print??
            return ___
    # what if we don't find the item?
    return ___

# Try it out:
print(student_search(namelist, names[0]))

# %% [markdown]
# **Difficulty:** ⭐⭐
#
# ### Task 3: Binary Search
# Write a function `student_search_b` that performs a linear search to find a student's ID by their name.

# %%
def student_search_b(namelist, target_name):
    # Your code here
    # first define the two pointers, left & right --
    left = ___
    right = ___

    # when do you run the loop until?
    while ___:
        # then, define the middle index, which is...?
        mid = ___

        # Your first compare!
        if ___ == ___:
            return ___
        # then what?
        elif ___:
            # reassign left to what?
            left = ___
        #then what?
        elif ___:
            # reassign right to what?
            right = ___

    # if we still can't find the target?
    return ___

# Try it out:
print(student_search_b(namelist, names[0]))

# %% [markdown]
# **Difficulty:** ⭐⭐
#
# ## Part 2: Collaborative Challenges 🤝 (Pair Programming)
# **Goal:** Build a multi-functional search system for a supermarket database.

# %%
products = ['Apples', 'Asparagus', 'Beef Stock', 'Chicken Breast', 'Butter', 'Milk', 'Bread', 'Jam', 'Lettuce', 'Ham']
ids = ['apl', 'asp', 'bfs', 'chk', 'btt', 'mlk', 'brd', 'jam', 'ltc', 'ham']
prices = [2.0, 1.7, 2.5, 4.5, 3.0, 3.0, 1.5, 2.2, 1.2, 5.0]

supermarket = {
    'name': products,
    'id': ids,
    'price': prices
}

print(prices.index(3.0))
print(products[4])
print(ids[4])
print(products[5])
print(ids[5])
# Out:
# 4
# Butter
# btt
# Milk
# mlk

# %% [markdown]
# **Difficulty:** ⭐⭐
#
# ### Task: The Versatile Search Function
# Work with your partner to create a `search()` function that:
# 1. Asks the user for input.
# 2. If input is a number, search by price.
# 3. If input is 3 letters long, search by ID.
# 4. Otherwise, search by name.
#
# Example Output:
# ```
# Enter search term (or '0' to quit): 3.0
#
# Results:
# Name: Butter, ID: btt, Price: $3.0
# Name: Milk, ID: mlk, Price: $3.0
# ------
# ```
#
# *Hint: You may wanna google about try except in Python, it can be useful in this question :)*

# %%
def search():
    """This function helps users search for a product in the supermarket by name, id or price."""
    while True:
        prompt = input("Enter search term (or '0' to quit): ")
        if prompt == '0': break
        # write your logic here
        pass

# %% [markdown]
# **Difficulty:** ⭐⭐
#
# ## Part 3: Homework 🏠 (Take Home)
# **Goal:** Debugging and optimizing searches using Binary Search.

# %% [markdown]
# **Difficulty:** ⭐
#
# ### Task 1: Debugging Linear Search
# The following code has errors. Find and fix them.

# %%
def broken_linear_search(arr, tgt):
    while i in range(len(ar)):
        if arr[i] == tgt:
            return i
    return -1

# %% [markdown]
# **Difficulty:** ⭐
#
# ### Task 2: Phonebook Sorting
# Implement a **bubble sort** function that sorts the phonebook by number.

# %%
# Sample Phonebook
phonebook = [('Bob', '555-0103'), ('Charlie', '555-0102'), ('Alice', '555-0101')]

def phone_sort(phonebook):
    # Write your sort function here
    pass

# %% [markdown]
# ---
#
# # 🤝 Group Activity
#
# **The Phonebook Race**
#
# In pairs, race linear search vs binary search. Generate a sorted list of 1,000,000 numbers. Each partner picks a search algorithm and finds the same random target. Time both with `time.time()` and compare. Discuss why one is faster.

# %%
import time, random

data = list(range(1_000_000))
target = random.choice(data)
# write code here

# %% [markdown]
# ---
#
# # 📊 Differentiated Practice
#
# Choose the level that challenges you most — try to work your way up!

# %% [markdown]
# ## Beginner ⭐
#
# Write a `linear_search(arr, target)` that returns the index of target, or -1.

# %%
def linear_search(arr, target):
    # write code here
    pass

# %% [markdown]
# ## Intermediate ⭐⭐
#
# Write a recursive binary search `binary_search(arr, target)` that returns the index or -1.

# %% [markdown]
# > 💡 *Hint:* Use left/right pointers and recurse on the correct half.

# %%
def binary_search(arr, target):
    # write code here
    pass

# %% [markdown]
# ## Advanced ⭐⭐⭐
#
# Write a function that counts how many comparisons linear search vs binary search make for the same target, then print both counts.

# %%
# write code here

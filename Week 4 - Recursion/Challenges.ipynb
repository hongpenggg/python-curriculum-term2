# %% [markdown]
# # Challenges: Recursion
#
# **Week 4 — Bit by Bit Coding (Term 2)**
#
# Today's challenges test your understanding of recursive functions, base cases, and recursive cases.
#
# **Difficulty levels:** ⭐ Beginner · ⭐⭐ Intermediate · ⭐⭐⭐ Advanced

# %% [markdown]
# ## Part 1: Micro-challenges 🔍 (Individual Practice)
#
# **Goal:** Write recursive functions that solve smaller versions of the same problem.

# %% [markdown]
# ### Task 1: Factorial
#
# **Difficulty:** ⭐
#
# Write a recursive function `factorial(n)` that returns `n!`. Remember: `0! = 1` is your base case.

# %%
# write code here

# %% [markdown]
# ### Task 2: Sum of Digits
#
# **Difficulty:** ⭐⭐
#
# Write a recursive `sum_digits(n)` that returns the sum of the digits of `n`.
#
# Example: `sum_digits(234) -> 9`.

# %%
# write code here

# %% [markdown]
# ### Task 3: nth Fibonacci
#
# **Difficulty:** ⭐⭐
#
# Write a recursive `fib(n)` returning the nth Fibonacci number (1, 1, 2, 3, 5, 8, ...).

# %%
# write code here

# %% [markdown]
# ### Task 4: Power Function
#
# **Difficulty:** ⭐⭐⭐
#
# Write a recursive `power(base, exp)` that returns `base ** exp` without using `**`. Also handle negative exponents.

# %%
# write code here

# %% [markdown]
# ---
#
# # 🤝 Group Activity
#
# **Recursive Countdown & Power**
#
# In pairs, write two recursive functions: `countdown(n)` that prints n, n-1, ... 1, Blastoff!, and `power(base, exp)` that returns base**exp using only recursion (no `**`). One partner writes `countdown`, the other writes `power`. Combine and trace each other's call stack on paper.

# %%
def countdown(n):
    # write code here
    pass

# %% [markdown]
# ---
#
# # 🏠 Homework
#
# *Take these home and attempt them before the next session. Difficulty markers are shown for each exercise.*

# %% [markdown]
# ## Fix-it 🔨 ⭐
#
# This factorial has no base case and recurses forever. Fix it.

# %%
def factorial(n):
    return n * factorial(n - 1)

print(factorial(5))

# %% [markdown]
# ## Predict 🔮 ⭐⭐
#
# What does `countdown(3)` print? Trace the calls.

# %%
def countdown(n):
    if n == 0:
        print("Blastoff!")
        return
    print(n)
    countdown(n - 1)

countdown(3)
# Prediction:

# %% [markdown]
# ## Fill-in-the-blanks ✏️ ⭐⭐
#
# Complete the recursive sum of digits function.

# %%
def sum_digits(n):
    if n == 0:
        return _______
    return (n % 10) + sum_digits(_______)

# %% [markdown]
# ---
#
# # 📊 Differentiated Practice
#
# Choose the level that challenges you most — try to work your way up!

# %% [markdown]
# ## Beginner ⭐
#
# Write a recursive `factorial(n)` that returns `n * factorial(n-1)` with base case `factorial(0) == 1`.

# %%
def factorial(n):
    # write code here
    pass

# %% [markdown]
# ## Intermediate ⭐⭐
#
# Write a recursive `sum_to(n)` that returns `1 + 2 + ... + n` using recursion.

# %% [markdown]
# > 💡 *Hint:* Base case: `sum_to(1) == 1`.

# %%
def sum_to(n):
    # write code here
    pass

# %% [markdown]
# ## Advanced ⭐⭐⭐
#
# Write a recursive `power(base, exp)` that returns `base ** exp` without using `**`. Handle `exp == 0` and also negative exponents.

# %%
def power(base, exp):
    # write code here
    pass

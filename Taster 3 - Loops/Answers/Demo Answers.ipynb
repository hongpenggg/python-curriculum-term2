# %% [markdown]
# #While loops
#
# Jack wants to play games 🎮. But alas, he still has way too much homework 📖📖📖 to do. He cannot play until he finishes ALL of his homework, or else he will get scolded!
#
# Help Jack finish his homework, by reducing the `homework` variable to zero with subtraction!
#
# 📖📖📖📖📖📖📖📖📖📖

# %%
homework = 100 #Jack has 100 pieces of homework.

#Use subtraction to reduce "homework" to 0
homework = homework - 100

print(homework)
# Out:
# 0

# %% [markdown]
# Oh, no! The next day, the teacher has just realised that Jack had finished all his homework at the same time (by subtracting a large number from "homework".) 😡😡😡
#
# The teacher declares that Jack must do only one piece of homework at a time!
#
# Jack tries to finish his homework using the code below, but he quickly gets tired of typing all the code...

# %%
homework = 100 #Jack has 100 pieces of homework.

homework = homework - 1 #Jack finishes one piece of homework.
homework = homework - 1 #Jack finishes another piece of homework.
homework = homework - 1 #...and another.
homework = homework - 1 #...and another.
homework = homework - 1 #...and another.
#Phew, Jack is getting tired from typing all these subtraction equations.

print(homework)
#And there are still 95 pieces of homework left!
# Out:
# 95

# %% [markdown]
# Help Jack out by using a while loop to make sure he keeps doing his homework until he runs out of homework to do! 🔃🔃🔃
#
# To make Jack do his homework until he runs out, we can use a **While loop.**
#
# Here's the format for a while loop:
#
#     while <condition>:
#         #The indented lines under the "while" statement executes every loop
#         print("Hello World") #Prints "Hello World" until the contition is False
#
#
# A while loop consists of
#
# **"while"** => The keyword starting the while loop.
#
# **condition** => A boolean (statement that results in True or False) that signals whether the while loop should end.
#
# **: (the colon)** => Syntax that separates the condition from the body. Goes right after the condition.
#
# **body** => The code inside the while loop that will keep running while the condition is true.
#
# **An example:**
# Keep eating while there is still rice remaining
#
# ```
# while rice > 0:
#     rice = rice - 1
# ```
# `rice = rice - 1` will keep repeating until `rice > 0` becomes `False`. That is, until the variable `rice` stores a number that is not more than 0 (i.e. 0 or negative numbers).
#
# To check whether Jack still has homework remaining, use the condition "homework > 0".

# %%
homework = 100 #Jack has 100 pieces of homework.

# Use a while loop!
while homework > 0:
    homework -= 1

print(f'Remaining homework: {homework}')
# Out:
# Remaining homework: 0

# %% [markdown]
# Change of plans! Jack is now allowed to take a **break** after he has finished 50 pieces of homework!
# Help Jack use the "break" statement in order to stop the while loop when homework reaches 50!

# %%
homework = 100

while homework > 0:
    if homework == 50:
        print('Time to take a break!')
        break
    homework -= 1

print(f'Remaining homework: {homework}')
# Out:
# Time to take a break!
# Remaining homework: 50

# %% [markdown]
# The teacher said that the 10th piece of homework is incorrect, and as a result the students no longer have to complete the 10th piece.
# Help Jack use the **continue** statement to skip the 10th piece of homework!
# The **continue** statement will terminate(quit) the current loop, but will still run the upcoming loops normally (unlike **break**.)

# %%
homework = 100

while homework > 0:
    homework -= 1
    if homework == 90: #10th piece of homework
        continue
    print(f'{homework} pieces of homework left')

# As you can see, the output skips from 91 to 89 pieces of homework left
# Out:
# 99 pieces of homework left
# 98 pieces of homework left
# 97 pieces of homework left
# 96 pieces of homework left
# 95 pieces of homework left
# 94 pieces of homework left
# 93 pieces of homework left
# 92 pieces of homework left
# 91 pieces of homework left
# 89 pieces of homework left
# 88 pieces of homework left
# 87 pieces of homework left
# 86 pieces of homework left
# 85 pieces of homework left
# 84 pieces of homework left
# 83 pieces of homework left
# 82 pieces of homework left
# 81 pieces of homework left
# 80 pieces of homework left
# 79 pieces of homework left
# 78 pieces of homework left
# 77 pieces of homework left
# 76 pieces of homework left
# 75 pieces of homework left
# 74 pieces of homework left
# 73 pieces of homework left
# 72 pieces of homework left
# 71 pieces of homework left
# 70 pieces of homework left
# 69 pieces of homework left
# 68 pieces of homework left
# 67 pieces of homework left
# 66 pieces of homework left
# 65 pieces of homework left
# ...

# %% [markdown]
# After helping Jack out, you now know how to make use of while loops!
# Try to think of situations where you can use while loops to help you code!
# Let your imagination run free!

# %%
# Start coding!

# %% [markdown]
# ---
# # Micro-challenge 1 🔍: The Stamina Bar (While Loops)

# %% [markdown]
# Your character is sprinting! Every second they sprint, their stamina decreases.
#
# 1. Create a variable `stamina` and set it to `10`.
# 2. Use a **while loop** to print the current stamina and then subtract `1` from it.
# 3. The loop should stop once `stamina` is no longer greater than `0`.
# 4. After the loop, print `"Out of breath!"`.

# %%
 # write code here

stamina = 10

while stamina > 0:
    stamina -= 1

print(f'Out of breath, stamina: {stamina}')
# Out:
# Out of breath, stamina: 0

# %% [markdown]
# ---
# #For Loops
# Jack grew up, and became more responsible. As a result, his parents allow him to go and play once he has finished **50** pieces of homework, instead of all of them! 😯😯😯
#
# To help Jack do exactly **50** pieces of homework, we can use a **For Loop**.
#
# Here's the format for a **For Loop**:
#
# ```
#     for i in range(number) :
#         #The indented lines under the "for" statement executes every loop
#         print("Hello World") #Prints "Hello World" every time the loop runs
# ```
# A for loop consists of
#
# **"for"** => The keyword that tells Python you are about to start a loop.
#
#
# **"i"** => The iterator variable. In each "round" of the loop, this variable automatically updates to the current number in the sequence.
#
# Note: Just like with arrays, you can name this anything (like for task in range(50):).
#
# **range()** => A built-in function that creates a sequence of numbers. By default, range(50) starts at 0 and goes up to (but does not include) 50. This results in exactly 50 iterations.
#
# **: (the colon)** => The required syntax that signals the end of the loop header and the beginning of the action.
#
# **body** => The indented code block. Everything inside this "body" will repeat for every number in the range.

# %%
print("Numbers from 1 to 4")
for i in range(1, 4):
    print(i)

print("Numbers from 0 to 4")
for i in range(4):
    print(i)

print("Numbers from 0 to 9, incrementing by 2")
for i in range(0, 9, 2):
    print(i)
# Out:
# Numbers from 1 to 4
# 1
# 2
# 3
# Numbers from 0 to 4
# 0
# 1
# 2
# 3
# Numbers from 0 to 9, incrementing by 2
# 0
# 2
# 4
# 6
# 8

# %% [markdown]
# Notice that the **brackets** `()` behind `range` can take either 1,2, or 3 numbers.
#
# If it takes 1 number, that number will be the "end".
# `range(end)` will consist of all integer numbers from 0 to the integer before "end".
# *It is important to note that if you only provide "end" and not "start", the list of numbers wil lalways start from 0 and not 1.
#
# If it takes 2 numbers, the first will be the "start", while the second will be the "end".
# `range(start, end)` will consist of all integer numbers from "start" to the integer before "end".
#
# If it takes 3 numbers, they will be "start", "end", and "step".
# `range(start, end, step)` will consist of integer numbers from start to the integer before "end", incrementing by an amount equal to "step".

# %% [markdown]
# For loops using `range()` will repeat as many times as there are numbers given by the `range()` function.
#
# During each loop, the variable will become the number given by `range()` for that loop.
# For example, for the first loop of `for i in range(5):` , the variable "i" will be equal to 0.
#
# You now know how to use `range()` to control how many times a for loop repeats. Now can you make Jack do exactly 50 pieces of homework?

# %%
homework = 100

for i in range(50):
    homework -= 1

print(f'Homework left: {homework}')
# Out:
# Homework left: 50

# %% [markdown]
# Now can you make John do every other piece of homework instead?
# (Hint: "Every other piece of homework" means that "step" = 2)

# %%
#Make Jack do every other piece of homework
homework = 100

for i in range(0, homework, 2):
    homework -= 2
    print(f'Homework left: {homework}')
# Out:
# Homework left: 98
# Homework left: 96
# Homework left: 94
# Homework left: 92
# Homework left: 90
# Homework left: 88
# Homework left: 86
# Homework left: 84
# Homework left: 82
# Homework left: 80
# Homework left: 78
# Homework left: 76
# Homework left: 74
# Homework left: 72
# Homework left: 70
# Homework left: 68
# Homework left: 66
# Homework left: 64
# Homework left: 62
# Homework left: 60
# Homework left: 58
# Homework left: 56
# Homework left: 54
# Homework left: 52
# Homework left: 50
# Homework left: 48
# Homework left: 46
# Homework left: 44
# Homework left: 42
# Homework left: 40
# Homework left: 38
# Homework left: 36
# Homework left: 34
# Homework left: 32
# Homework left: 30
# Homework left: 28
# Homework left: 26
# Homework left: 24
# Homework left: 22
# Homework left: 20
# Homework left: 18
# Homework left: 16
# Homework left: 14
# Homework left: 12
# Homework left: 10
# Homework left: 8
# Homework left: 6
# Homework left: 4
# Homework left: 2
# Homework left: 0

# %% [markdown]
# ---
# # Micro-challenge 2 🔍: The Level Up (For Loops)
#
# You found a Rare Candy! It increases your level 5 times in a row.
#
# 1. Use a **for loop** and `range()` to print the message `"Level Up!"` exactly **5 times**.
# 2. **Bonus**: Use the iterator variable (e.g., `i`) to print which level you are on (1 to 5).

# %%
# write code here

for level in range(1, 6):
    print(f'Level Up! You are now Level {level}')
# Out:
# Level Up! You are now Level 1
# Level Up! You are now Level 2
# Level Up! You are now Level 3
# Level Up! You are now Level 4
# Level Up! You are now Level 5

# %% [markdown]
# ---
# **break** and **continue** also work on for loops.
#
# Can you try using them to customise and enhance your loops even further?
#
# Go wild! 🔥🔥🔥
#
# *Actually, you can even use for loops that count backwards!*

# %% [markdown]
# ---
# # Micro-challenge 3 🔍: The Restricted Zone (Break and Continue)
#
# A guard is counting people entering a gate (numbers 1 to 10).
#
# 1. Use a **for loop** that counts from 1 to 10 people.
# 2. Skip person `4` because they have a VIP pass.
# 3. Person `8` blocks the gate! Exit the loop.
# 4. Print the number of each person that has entered the gate

# %%
# write code here

for i in range(1, 11):
    if i == 4:
        print(f'Person {i} has a VIP pass.')
        continue
    elif i == 8:
        print(f'Person {i} is blocking the gate!')
        break
    print(f'Person {i} entered the gate. ')
# Out:
# Person 1 entered the gate.
# Person 2 entered the gate.
# Person 3 entered the gate.
# Person 4 has a VIP pass.
# Person 5 entered the gate.
# Person 6 entered the gate.
# Person 7 entered the gate.
# Person 8 is blocking the gate!
